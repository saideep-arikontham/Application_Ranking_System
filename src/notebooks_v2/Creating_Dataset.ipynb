# %% [markdown]
# # Creating Dataset

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import huggingface_hub

from datasets import DatasetDict, Dataset

import warnings
warnings.filterwarnings("ignore")

# %%
path = "/Users/saideep_arikontham/Projects/Application_Ranking_System"

# %% [markdown]
# ## Reading the data

# %%
df = pd.read_csv(f"{path}/data/synthetic_data/synthetic_data_v2/synthetic_data_v2.csv")
df
# Out:
#                                                job_data  \
# 0     Audit Manager\nMenzies LLP\nWe are looking for...
# 1     Audit Manager\nMenzies LLP\nWe are looking for...
# 2     Audit Manager\nMenzies LLP\nWe are looking for...
# 3     Audit Manager\nMenzies LLP\nWe are looking for...
# 4     Audit Manager\nOverview\nBaker Tilly US, LLP (...
# ...                                                 ...
# 3995  Test Engineer\nJob Summary:\nPerforms LAT test...
# 3996  Test Engineer\nCompany Description\nMUST be au...
# 3997  Test Engineer\nCompany Description\nMUST be au...
# 3998  Test Engineer\nCompany Description\nMUST be au...
# 3999  Test Engineer\nCompany Description\nMUST be au...
#
#                                             resume_data              label
# 0     **Jennifer Oneal**\n*+1 (555) 555-5555* *|* *j...  Complete Mismatch
# 1     **Christina Padilla DVM**\n\n*Email: christina...      Underwhelming
# 2     **Andrew Kirby**\n*+44 00000 000000* *|* *andr...           Good Fit
# 3     **Erin Hicks**\n*+1 (555) 555-5555* *|* *erin....      Overqualified
# 4     **Randy Smith**\n*+1 (123) 456-7890* *|* *rand...  Complete Mismatch
# ...                                                 ...                ...
# 3995  # Darren Roberts\n\n*Email*: darren.roberts@em...      Overqualified
# 3996  **Lisa Wright**\n*+1 (111) 111-1111* *|* *lisa...  Complete Mismatch
# 3997  # Daniel Meza\n\n*Greensboro, NC* *·* *(555) 5...      Underwhelming
# 3998  # William Torres\n\n*Greensboro, NC* *|* *will...           Good Fit
# 3999  # Robert Ramsey\n\n*Greensboro, NC | (555) 555...      Overqualified
#
# [4000 rows x 3 columns]

# %%
revised_label_map = {"Complete Mismatch": "Bad Fit", "Underwhelming":"Bad Fit", "Good Fit":"Good Fit", "Overqualified":"Good Fit"}
df['label'] = df['label'].map(revised_label_map)
df['label'].value_counts()
# Out:
# label
# Bad Fit     2000
# Good Fit    2000
# Name: count, dtype: int64

# %%
print("Number of rows in the dataset:", df.shape[0])
print("Number of columns in the dataset:", df.shape[1])
# Out:
# Number of rows in the dataset: 4000
# Number of columns in the dataset: 3

# %%
df
# Out:
#                                                job_data  \
# 0     Audit Manager\nMenzies LLP\nWe are looking for...
# 1     Audit Manager\nMenzies LLP\nWe are looking for...
# 2     Audit Manager\nMenzies LLP\nWe are looking for...
# 3     Audit Manager\nMenzies LLP\nWe are looking for...
# 4     Audit Manager\nOverview\nBaker Tilly US, LLP (...
# ...                                                 ...
# 3995  Test Engineer\nJob Summary:\nPerforms LAT test...
# 3996  Test Engineer\nCompany Description\nMUST be au...
# 3997  Test Engineer\nCompany Description\nMUST be au...
# 3998  Test Engineer\nCompany Description\nMUST be au...
# 3999  Test Engineer\nCompany Description\nMUST be au...
#
#                                             resume_data     label
# 0     **Jennifer Oneal**\n*+1 (555) 555-5555* *|* *j...   Bad Fit
# 1     **Christina Padilla DVM**\n\n*Email: christina...   Bad Fit
# 2     **Andrew Kirby**\n*+44 00000 000000* *|* *andr...  Good Fit
# 3     **Erin Hicks**\n*+1 (555) 555-5555* *|* *erin....  Good Fit
# 4     **Randy Smith**\n*+1 (123) 456-7890* *|* *rand...   Bad Fit
# ...                                                 ...       ...
# 3995  # Darren Roberts\n\n*Email*: darren.roberts@em...  Good Fit
# 3996  **Lisa Wright**\n*+1 (111) 111-1111* *|* *lisa...   Bad Fit
# 3997  # Daniel Meza\n\n*Greensboro, NC* *·* *(555) 5...   Bad Fit
# 3998  # William Torres\n\n*Greensboro, NC* *|* *will...  Good Fit
# 3999  # Robert Ramsey\n\n*Greensboro, NC | (555) 555...  Good Fit
#
# [4000 rows x 3 columns]

# %%
# Example mapping: adjust as necessary for your labels
label_list = sorted(df['label'].unique())
label2id = {label: i for i, label in enumerate(label_list)}
print(label2id)
df['label'] = df['label'].map(label2id)
df['label'].value_counts()
# Out:
# {'Bad Fit': 0, 'Good Fit': 1}
# label
# 0    2000
# 1    2000
# Name: count, dtype: int64

# %%
def get_title(text):
    return text.split("\n")[0]

# %% [markdown]
# ## Analyzing Job titles

# %%
df['job_title'] = df['job_data'].apply(lambda x: get_title(x))
job_titles = df['job_title'].unique().tolist()
print(job_titles)
# Out:
# ['Audit Manager', 'Automation Engineer', 'Business Development Representative', 'Business Intelligence Analyst', 'CNC Machinist', 'Construction Supervisor', 'Data Analyst', 'Data Engineer', 'Data Scientist', 'DevOps Engineer', 'Electrician', 'Embedded Software Engineer', 'Enterprise Architect', 'Facilities Manager', 'Financial Analyst', 'HR Manager', 'Lead Data Engineer', 'Marketing Coordinator', 'Physical Therapist', 'Physician', 'Plant Controller', 'Production Planner', 'Project Coordinator', 'Quality Assurance Engineer', 'Quality Control Inspector', 'Research Scientist', 'Retail Store Manager', 'Sales Manager', 'Senior Data Analyst', 'Senior Data Engineer', 'Senior Data Scientist', 'Senior DevOps Engineer', 'Senior Embedded Software Engineer', 'Senior Full Stack Developer', 'Senior Product Designer', 'Senior Quality Engineer', 'Senior Site Reliability Engineer', 'Senior Software Developer', 'Senior System Engineer', 'Senior Systems Engineer', 'Senior Tax Accountant', 'Senior Test Engineer', 'Software Developer', 'Software Engineer', 'Solution Architect', 'Solutions Architect', 'Supply Chain Manager', 'System Engineer', 'Systems Engineer', 'Test Engineer']

# %% [markdown]
# ### Selecting job titles for train, val, test split

# %%
# Train Data (40 Titles)
train_titles = [
    "Audit Manager", "Automation Engineer", "Business Development Representative", "Business Intelligence Analyst",
    "Construction Supervisor", "Data Analyst", "Data Engineer", "Data Scientist", "DevOps Engineer",
    "Embedded Software Engineer", "Enterprise Architect", "Facilities Manager", "Financial Analyst", "HR Manager",
    "Lead Data Engineer", "Marketing Coordinator", "Plant Controller", "Production Planner", "Project Coordinator",
    "Quality Assurance Engineer", "Quality Control Inspector", "Research Scientist", "Sales Manager",
    "Senior Data Analyst", "Senior Data Engineer", "Senior Data Scientist", "Senior DevOps Engineer",
    "Senior Embedded Software Engineer", "Senior Full Stack Developer", "Senior Product Designer",
    "Senior Quality Engineer", "Senior Site Reliability Engineer", "Senior Software Developer",
    "Senior System Engineer", "Senior Systems Engineer", "Senior Tax Accountant", "Senior Test Engineer",
    "Software Developer", "Software Engineer", "Supply Chain Manager"
]

# Validation Data (5 Titles)
val_titles = [
    "Solution Architect", "Solutions Architect", "System Engineer", "Systems Engineer", "Test Engineer"
]

# Test Data (5 Titles) - Significantly Different
test_titles = [
    "Physician", "Electrician", "CNC Machinist", "Physical Therapist", "Retail Store Manager"
]

# %% [markdown]
# ### Checking for any common job titles among train, val, test

# %%
print("Number of common job titles between train and validation titles selected: ", len(set(train_titles).intersection(val_titles)))
print("Number of common job titles between validation and test titles selected: ", len(set(val_titles).intersection(test_titles)))
print("Number of common job titles between test and train titles selected: ", len(set(test_titles).intersection(train_titles)))
# Out:
# Number of common job titles between train and validation titles selected:  0
# Number of common job titles between validation and test titles selected:  0
# Number of common job titles between test and train titles selected:  0

# %% [markdown]
# ## Creating Train, Val, test data

# %% [markdown]
# ### Train data

# %%
train_df = df[df['job_title'].isin(train_titles)].drop(['job_title'], axis=1)
train_df
# Out:
#                                                job_data  \
# 0     Audit Manager\nMenzies LLP\nWe are looking for...
# 1     Audit Manager\nMenzies LLP\nWe are looking for...
# 2     Audit Manager\nMenzies LLP\nWe are looking for...
# 3     Audit Manager\nMenzies LLP\nWe are looking for...
# 4     Audit Manager\nOverview\nBaker Tilly US, LLP (...
# ...                                                 ...
# 3875  Supply Chain Manager\nManitoba Harvest - Winni...
# 3876  Supply Chain Manager\n"Fuel your future with u...
# 3877  Supply Chain Manager\n"Fuel your future with u...
# 3878  Supply Chain Manager\n"Fuel your future with u...
# 3879  Supply Chain Manager\n"Fuel your future with u...
#
#                                             resume_data  label
# 0     **Jennifer Oneal**\n*+1 (555) 555-5555* *|* *j...      0
# 1     **Christina Padilla DVM**\n\n*Email: christina...      0
# 2     **Andrew Kirby**\n*+44 00000 000000* *|* *andr...      1
# 3     **Erin Hicks**\n*+1 (555) 555-5555* *|* *erin....      1
# 4     **Randy Smith**\n*+1 (123) 456-7890* *|* *rand...      0
# ...                                                 ...    ...
# 3875  **Tina Green**\n*+1 (234) 567-8901* *|* *tina....      1
# 3876  # Nicole Bailey\n\n*Irving, TX 750xxxxxxxx | n...      0
# 3877  **Kimberly Hernandez**\n*Irving, TX | (214) 55...      0
# 3878  **ALYSSA BALDWIN**\n\n*(+1) 555-555-5555* *|* ...      1
# 3879  **Jamie Jones**\n*+1 (111) 111-1111* *·* *jami...      1
#
# [3200 rows x 3 columns]

# %% [markdown]
# #### Train label distribution

# %%
train_df['label'].value_counts()
# Out:
# label
# 0    1600
# 1    1600
# Name: count, dtype: int64

# %% [markdown]
# ### Validation data

# %%
val_df = df[df['job_title'].isin(val_titles)].drop(['job_title'], axis=1)
val_df
# Out:
#                                                job_data  \
# 2760  Solution Architect\nNumber Of Positions Availa...
# 2761  Solution Architect\nNumber Of Positions Availa...
# 2762  Solution Architect\nNumber Of Positions Availa...
# 2763  Solution Architect\nNumber Of Positions Availa...
# 2764  Solution Architect\nSecurity Clearance Require...
# ...                                                 ...
# 3995  Test Engineer\nJob Summary:\nPerforms LAT test...
# 3996  Test Engineer\nCompany Description\nMUST be au...
# 3997  Test Engineer\nCompany Description\nMUST be au...
# 3998  Test Engineer\nCompany Description\nMUST be au...
# 3999  Test Engineer\nCompany Description\nMUST be au...
#
#                                             resume_data  label
# 2760  **Billy Dickson**\n*+1 (123) 456-7890* *|* *bi...      0
# 2761  **KEVIN FORD**\n\n*+1 (xxx) xxx-xxxx* | *kevin...      0
# 2762  **KRYSTAL DAVIS**\n\n*+61 4 0000 0000* *|* *kr...      1
# 2763  **Leslie Perry**\n\n*+1 (123) 456-7890* | *les...      1
# 2764  # James Bailey\n\n*Chippenham, UK* *+44 7xxx x...      0
# ...                                                 ...    ...
# 3995  # Darren Roberts\n\n*Email*: darren.roberts@em...      1
# 3996  **Lisa Wright**\n*+1 (111) 111-1111* *|* *lisa...      0
# 3997  # Daniel Meza\n\n*Greensboro, NC* *·* *(555) 5...      0
# 3998  # William Torres\n\n*Greensboro, NC* *|* *will...      1
# 3999  # Robert Ramsey\n\n*Greensboro, NC | (555) 555...      1
#
# [400 rows x 3 columns]

# %% [markdown]
# #### Validation label distribution

# %%
val_df['label'].value_counts()
# Out:
# label
# 0    200
# 1    200
# Name: count, dtype: int64

# %% [markdown]
# ### Test data

# %%
test_df = df[df['job_title'].isin(test_titles)].drop(['job_title'], axis=1)
test_df
# Out:
#                                                job_data  \
# 160   CNC Machinist\nLoc Performance Products, LLC p...
# 161   CNC Machinist\nLoc Performance Products, LLC p...
# 162   CNC Machinist\nLoc Performance Products, LLC p...
# 163   CNC Machinist\nLoc Performance Products, LLC p...
# 164   CNC Machinist\nJC Ford - Tennessee is seeking ...
# ...                                                 ...
# 3075  Retail Store Manager\nAt Nespresso we place pe...
# 3076  Retail Store Manager\nThe Retail Store Manager...
# 3077  Retail Store Manager\nThe Retail Store Manager...
# 3078  Retail Store Manager\nThe Retail Store Manager...
# 3079  Retail Store Manager\nThe Retail Store Manager...
#
#                                             resume_data  label
# 160   **DONNA JONES**\n\n*donnajones@email.com* · (1...      0
# 161   **Ann Nelson**\n(555) 555-5555 | ann.nelson@em...      0
# 162   **Adam Johnson**\n\n*+1 (123) 456-7890* *|* *a...      1
# 163   # MARK MURRAY\n\n*Plymouth, MI* *|* *555-555-5...      1
# 164   # Tim Young\n\n*Nashville, TN* *|* *(615) 555-...      0
# ...                                                 ...    ...
# 3075  # WILLIAM BROWN\n\n*Email*: william.brown@emai...      1
# 3076  **Cory Mullins**\n*555-555-5555* *cory.mullins...      0
# 3077  **Catherine Church**\n*+1 (xxx) xxx- xxxx* *|*...      0
# 3078  **Franklin Gardner**\n*Phone: (555) 555-5555* ...      1
# 3079  # Alexander Werner\n\n*Email*: alexanderwerner...      1
#
# [400 rows x 3 columns]

# %% [markdown]
# #### Test label distribution

# %%
test_df['label'].value_counts()
# Out:
# label
# 0    200
# 1    200
# Name: count, dtype: int64

# %% [markdown]
# ### Checking for matching indices

# %%
print("Number of common indices between train and validation data: ", len(set(train_df.index.tolist()).intersection(val_df.index)))
print("Number of common indices between validation and test data: ", len(set(val_df.index.tolist()).intersection(test_df.index)))
print("Number of common indices between test and train titles selected: ", len(set(test_df.index.tolist()).intersection(train_df.index)))
# Out:
# Number of common indices between train and validation data:  0
# Number of common indices between validation and test data:  0
# Number of common indices between test and train titles selected:  0

# %% [markdown]
# Therefore, No data is missed

# %% [markdown]
# ## Creating dataset

# %%
# # -------------------------------
# # Creating Dataset
# # -------------------------------

# Convert Pandas DataFrames to Hugging Face Datasets
train_dataset = Dataset.from_pandas(train_df)
val_dataset = Dataset.from_pandas(val_df)
test_dataset = Dataset.from_pandas(test_df)

# Create a DatasetDict with train, validation, and test splits
dataset = DatasetDict({
    "train": train_dataset,
    "validation": val_dataset,
    "test": test_dataset
})
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['job_data', 'resume_data', 'label', '__index_level_0__'],
#         num_rows: 3200
#     })
#     validation: Dataset({
#         features: ['job_data', 'resume_data', 'label', '__index_level_0__'],
#         num_rows: 400
#     })
#     test: Dataset({
#         features: ['job_data', 'resume_data', 'label', '__index_level_0__'],
#         num_rows: 400
#     })
# })

# %% [markdown]
# ## Saving to disk

# %%
dataset.save_to_disk(f"{path}/data/jd_resume_dataset")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/3200 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/400 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/400 [00:00<?, ? examples/s]

# %% [markdown]
# ## Saving to Huggingface Datasets

# %%
huggingface_hub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
dataset.push_to_hub("saideep-arikontham/jd_resume_dataset")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /opt/anaconda3/envs/ARS/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File /opt/anaconda3/envs/ARS/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/repos/create
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 dataset.push_to_hub("saideep-arikontham/jd_resume_dataset")
#
# File /opt/anaconda3/envs/ARS/lib/python3.12/site-packages/datasets/dataset_dict.py:1645, in DatasetDict.push_to_hub(self, repo_id, config_name, set_default, data_dir, commit_message, commit_description, private, token, revision, create_pr, max_shard_size, num_shards, embed_external_files)
#    1641         raise ValueError(f"Split name should match '{_split_re}' but got '{split}'.")
#    1643 api = HfApi(endpoint=config.HF_ENDPOINT, token=token)
# -> 1645 repo_url = api.create_repo(
#    1646     repo_id,
#    1647     token=token,
#    1648     repo_type="dataset",
#    1649     private=private,
#    1650     exist_ok=True,
#    1651 )
#    1652 repo_id = repo_url.repo_id
#    1654 if revision is not None and not revision.startswith("refs/pr/"):
#    1655     # We do not call create_branch for a PR reference: 400 Bad Request
#
# File /opt/anaconda3/envs/ARS/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File /opt/anaconda3/envs/ARS/lib/python3.12/site-packages/huggingface_hub/hf_api.py:3511, in HfApi.create_repo(self, repo_id, token, private, repo_type, exist_ok, resource_group_id, space_sdk, space_hardware, space_storage, space_sleep_time, space_secrets, space_variables)
#    3508     break
#    3510 try:
# -> 3511     hf_raise_for_status(r)
#    3512 except HTTPError as err:
#    3513     if exist_ok and err.response.status_code == 409:
#    3514         # Repo already exists and `exist_ok=True`
#
# File /opt/anaconda3/envs/ARS/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:481, in hf_raise_for_status(response, endpoint_name)
#     477     raise _format(HfHubHTTPError, message, response) from e
#     479 # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     480 # as well (request id and/or server error message)
# --> 481 raise _format(HfHubHTTPError, str(e), response) from e
#
# HfHubHTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/repos/create (Request ID: Root=1-67d0ea37-17581adb04c0584e1f1f4520;839226dc-1904-4dc9-b067-2d7543d20ed3)
#
# Invalid username or password.
