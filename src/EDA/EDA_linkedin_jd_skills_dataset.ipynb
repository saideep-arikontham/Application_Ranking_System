# %% [markdown]
# # EDA

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
import sys
from pathlib import Path

path = Path(os.path.dirname(os.getcwd()))
path = str(path)
print(path)
sys.path.insert(1, path)
# Out:
# /Users/saideepbunny/Projects/Application_Ranking_System

# %% [markdown]
# ## Reading the data

# %%
df1 = pd.read_csv(f"{path}/data/kaggle_linkedin_jd_skills_dataset/job_skills.csv")
df2 = pd.read_csv(f"{path}/data/kaggle_linkedin_jd_skills_dataset/job_summary.csv")
df3 = pd.read_csv(f"{path}/data/kaggle_linkedin_jd_skills_dataset/linkedin_job_postings.csv")
df3
# Out:
#                                                   job_link  \
# 0        https://www.linkedin.com/jobs/view/account-exe...
# 1        https://www.linkedin.com/jobs/view/registered-...
# 2        https://www.linkedin.com/jobs/view/restaurant-...
# 3        https://www.linkedin.com/jobs/view/independent...
# 4        https://www.linkedin.com/jobs/view/group-unit-...
# ...                                                    ...
# 1348449  https://www.linkedin.com/jobs/view/registered-...
# 1348450  https://www.linkedin.com/jobs/view/constructio...
# 1348451  https://www.linkedin.com/jobs/view/executive-c...
# 1348452  https://www.linkedin.com/jobs/view/rn-register...
# 1348453  https://www.linkedin.com/jobs/view/on-demand-g...
#
#                    last_processed_time got_summary got_ner is_being_worked  \
# 0         2024-01-21 07:12:29.00256+00           t       t               f
# 1         2024-01-21 07:39:58.88137+00           t       t               f
# 2        2024-01-21 07:40:00.251126+00           t       t               f
# 3        2024-01-21 07:40:00.308133+00           t       t               f
# 4        2024-01-19 09:45:09.215838+00           f       f               f
# ...                                ...         ...     ...             ...
# 1348449  2024-01-20 15:21:07.786118+00           t       t               f
# 1348450  2024-01-20 15:21:10.885264+00           t       t               f
# 1348451  2024-01-21 07:40:00.304641+00           t       t               f
# 1348452  2024-01-21 00:38:39.816821+00           t       t               f
# 1348453  2024-01-21 00:38:44.231492+00           t       t               f
#
#                                                  job_title  \
# 0        Account Executive - Dispensing (NorCal/Norther...
# 1                       Registered Nurse - RN Care Manager
# 2                     RESTAURANT SUPERVISOR - THE FORKLIFT
# 3                            Independent Real Estate Agent
# 4        Group/Unit Supervisor (Systems Support Manager...
# ...                                                    ...
# 1348449  Registered Nurse (RN) #CP-RN-7998660 - 2411627...
# 1348450                        Construction Superintendent
# 1348451                 Executive Chef, Operations Support
# 1348452  RN- Registered Nurse, Analyst - - 23934913EXPP...
# 1348453  On-Demand: Guest Advocate (Cashier), General M...
#
#                               company          job_location  first_seen  \
# 0                                  BD         San Diego, CA  2024-01-15
# 1                   Trinity Health MI     Norton Shores, MI  2024-01-14
# 2             Wasatch Adaptive Sports             Sandy, UT  2024-01-14
# 3          Howard Hanna | Rand Realty  Englewood Cliffs, NJ  2024-01-16
# 4        IRS, Office of Chief Counsel          Chamblee, GA  2024-01-17
# ...                               ...                   ...         ...
# 1348449             TravelNurseSource        Providence, RI  2024-01-14
# 1348450                         Jobot        New Iberia, LA  2024-01-15
# 1348451           NEXDINE Hospitality         Riverhead, NY  2024-01-14
# 1348452             TravelNurseSource            Aurora, CO  2024-01-16
# 1348453                        Target       Culver City, CA  2024-01-12
#
#          search_city search_country                        search_position  \
# 0           Coronado  United States                            Color Maker
# 1        Grand Haven  United States               Director Nursing Service
# 2             Tooele  United States                               Stand-In
# 3          Pinehurst  United States                      Real-Estate Clerk
# 4            Gadsden  United States   Supervisor Travel-Information Center
# ...              ...            ...                                    ...
# 1348449   Fall River  United States                       Nurse Supervisor
# 1348450    Lafayette  United States  Assistant Construction Superintendent
# 1348451     Eastport  United States                                   Chef
# 1348452     Colorado  United States                   Occupational Analyst
# 1348453       Malibu  United States                             Cashier Ii
#
#           job_level job_type
# 0        Mid senior   Onsite
# 1        Mid senior   Onsite
# 2        Mid senior   Onsite
# 3        Mid senior   Onsite
# 4        Mid senior   Onsite
# ...             ...      ...
# 1348449  Mid senior   Onsite
# 1348450  Mid senior   Onsite
# 1348451  Mid senior   Onsite
# 1348452  Mid senior   Onsite
# 1348453  Mid senior   Onsite
#
# [1348454 rows x 14 columns]

# %%
df = df3.merge(df1, on='job_link', how='inner').merge(df2, on='job_link', how='inner')
df
# Out:
#                                                   job_link  \
# 0        https://www.linkedin.com/jobs/view/account-exe...
# 1        https://www.linkedin.com/jobs/view/registered-...
# 2        https://www.linkedin.com/jobs/view/restaurant-...
# 3        https://www.linkedin.com/jobs/view/independent...
# 4        https://www.linkedin.com/jobs/view/registered-...
# ...                                                    ...
# 1296376  https://www.linkedin.com/jobs/view/registered-...
# 1296377  https://www.linkedin.com/jobs/view/constructio...
# 1296378  https://www.linkedin.com/jobs/view/executive-c...
# 1296379  https://www.linkedin.com/jobs/view/rn-register...
# 1296380  https://www.linkedin.com/jobs/view/on-demand-g...
#
#                    last_processed_time got_summary got_ner is_being_worked  \
# 0         2024-01-21 07:12:29.00256+00           t       t               f
# 1         2024-01-21 07:39:58.88137+00           t       t               f
# 2        2024-01-21 07:40:00.251126+00           t       t               f
# 3        2024-01-21 07:40:00.308133+00           t       t               f
# 4        2024-01-21 08:08:19.663033+00           t       t               f
# ...                                ...         ...     ...             ...
# 1296376  2024-01-20 15:21:07.786118+00           t       t               f
# 1296377  2024-01-20 15:21:10.885264+00           t       t               f
# 1296378  2024-01-21 07:40:00.304641+00           t       t               f
# 1296379  2024-01-21 00:38:39.816821+00           t       t               f
# 1296380  2024-01-21 00:38:44.231492+00           t       t               f
#
#                                                  job_title  \
# 0        Account Executive - Dispensing (NorCal/Norther...
# 1                       Registered Nurse - RN Care Manager
# 2                     RESTAURANT SUPERVISOR - THE FORKLIFT
# 3                            Independent Real Estate Agent
# 4                                    Registered Nurse (RN)
# ...                                                    ...
# 1296376  Registered Nurse (RN) #CP-RN-7998660 - 2411627...
# 1296377                        Construction Superintendent
# 1296378                 Executive Chef, Operations Support
# 1296379  RN- Registered Nurse, Analyst - - 23934913EXPP...
# 1296380  On-Demand: Guest Advocate (Cashier), General M...
#
#                             company          job_location  first_seen  \
# 0                                BD         San Diego, CA  2024-01-15
# 1                 Trinity Health MI     Norton Shores, MI  2024-01-14
# 2           Wasatch Adaptive Sports             Sandy, UT  2024-01-14
# 3        Howard Hanna | Rand Realty  Englewood Cliffs, NJ  2024-01-16
# 4                 Trinity Health MI          Muskegon, MI  2024-01-14
# ...                             ...                   ...         ...
# 1296376           TravelNurseSource        Providence, RI  2024-01-14
# 1296377                       Jobot        New Iberia, LA  2024-01-15
# 1296378         NEXDINE Hospitality         Riverhead, NY  2024-01-14
# 1296379           TravelNurseSource            Aurora, CO  2024-01-16
# 1296380                      Target       Culver City, CA  2024-01-12
#
#          search_city search_country                        search_position  \
# 0           Coronado  United States                            Color Maker
# 1        Grand Haven  United States               Director Nursing Service
# 2             Tooele  United States                               Stand-In
# 3          Pinehurst  United States                      Real-Estate Clerk
# 4           Muskegon  United States                     Nurse Practitioner
# ...              ...            ...                                    ...
# 1296376   Fall River  United States                       Nurse Supervisor
# 1296377    Lafayette  United States  Assistant Construction Superintendent
# 1296378     Eastport  United States                                   Chef
# 1296379     Colorado  United States                   Occupational Analyst
# 1296380       Malibu  United States                             Cashier Ii
#
#           job_level job_type  \
# 0        Mid senior   Onsite
# 1        Mid senior   Onsite
# 2        Mid senior   Onsite
# 3        Mid senior   Onsite
# 4        Mid senior   Onsite
# ...             ...      ...
# 1296376  Mid senior   Onsite
# 1296377  Mid senior   Onsite
# 1296378  Mid senior   Onsite
# 1296379  Mid senior   Onsite
# 1296380  Mid senior   Onsite
#
#                                                 job_skills  \
# 0        Medical equipment sales, Key competitors, Term...
# 1        Nursing, Bachelor of Science in Nursing, Maste...
# 2        Restaurant Operations Management, Inventory Ma...
# 3        Real Estate, Customer Service, Sales, Negotiat...
# 4        Nursing, BSN, Medical License, Virtual RN, Nur...
# ...                                                    ...
# 1296376  Registered Nurse, BLS certification, Nursing c...
# 1296377  Construction management, Project planning, Est...
# 1296378  Culinary, Chef Director, Menu writing, Cycle o...
# 1296379  Registered Nurse, Analyst, RN Registered Nurse...
# 1296380  Customer service, Communication, Problem solvi...
#
#                                                job_summary
# 0        Responsibilities\nJob Description Summary\nJob...
# 1        Employment Type:\nFull time\nShift:\nDescripti...
# 2        Job Details\nDescription\nWhat You'll Do\nAs a...
# 3        Who We Are\nRand Realty is a family-owned brok...
# 4        Employment Type:\nFull time\nShift:\n12 Hour N...
# ...                                                    ...
# 1296376  TravelNurseSource is working with Adelphi Medi...
# 1296377  Want to learn more about this role and Jobot? ...
# 1296378  NEXDINE HOSPITALITY one of the nation's fastes...
# 1296379  TravelNurseSource is working with Alliant Pers...
# 1296380  Description: Starting Hourly Rate / Salario po...
#
# [1296381 rows x 16 columns]

# %%
df['id'] = list(range(df.shape[0]))
df
# Out:
#                                                   job_link  \
# 0        https://www.linkedin.com/jobs/view/account-exe...
# 1        https://www.linkedin.com/jobs/view/registered-...
# 2        https://www.linkedin.com/jobs/view/restaurant-...
# 3        https://www.linkedin.com/jobs/view/independent...
# 4        https://www.linkedin.com/jobs/view/registered-...
# ...                                                    ...
# 1296376  https://www.linkedin.com/jobs/view/registered-...
# 1296377  https://www.linkedin.com/jobs/view/constructio...
# 1296378  https://www.linkedin.com/jobs/view/executive-c...
# 1296379  https://www.linkedin.com/jobs/view/rn-register...
# 1296380  https://www.linkedin.com/jobs/view/on-demand-g...
#
#                    last_processed_time got_summary got_ner is_being_worked  \
# 0         2024-01-21 07:12:29.00256+00           t       t               f
# 1         2024-01-21 07:39:58.88137+00           t       t               f
# 2        2024-01-21 07:40:00.251126+00           t       t               f
# 3        2024-01-21 07:40:00.308133+00           t       t               f
# 4        2024-01-21 08:08:19.663033+00           t       t               f
# ...                                ...         ...     ...             ...
# 1296376  2024-01-20 15:21:07.786118+00           t       t               f
# 1296377  2024-01-20 15:21:10.885264+00           t       t               f
# 1296378  2024-01-21 07:40:00.304641+00           t       t               f
# 1296379  2024-01-21 00:38:39.816821+00           t       t               f
# 1296380  2024-01-21 00:38:44.231492+00           t       t               f
#
#                                                  job_title  \
# 0        Account Executive - Dispensing (NorCal/Norther...
# 1                       Registered Nurse - RN Care Manager
# 2                     RESTAURANT SUPERVISOR - THE FORKLIFT
# 3                            Independent Real Estate Agent
# 4                                    Registered Nurse (RN)
# ...                                                    ...
# 1296376  Registered Nurse (RN) #CP-RN-7998660 - 2411627...
# 1296377                        Construction Superintendent
# 1296378                 Executive Chef, Operations Support
# 1296379  RN- Registered Nurse, Analyst - - 23934913EXPP...
# 1296380  On-Demand: Guest Advocate (Cashier), General M...
#
#                             company          job_location  first_seen  \
# 0                                BD         San Diego, CA  2024-01-15
# 1                 Trinity Health MI     Norton Shores, MI  2024-01-14
# 2           Wasatch Adaptive Sports             Sandy, UT  2024-01-14
# 3        Howard Hanna | Rand Realty  Englewood Cliffs, NJ  2024-01-16
# 4                 Trinity Health MI          Muskegon, MI  2024-01-14
# ...                             ...                   ...         ...
# 1296376           TravelNurseSource        Providence, RI  2024-01-14
# 1296377                       Jobot        New Iberia, LA  2024-01-15
# 1296378         NEXDINE Hospitality         Riverhead, NY  2024-01-14
# 1296379           TravelNurseSource            Aurora, CO  2024-01-16
# 1296380                      Target       Culver City, CA  2024-01-12
#
#          search_city search_country                        search_position  \
# 0           Coronado  United States                            Color Maker
# 1        Grand Haven  United States               Director Nursing Service
# 2             Tooele  United States                               Stand-In
# 3          Pinehurst  United States                      Real-Estate Clerk
# 4           Muskegon  United States                     Nurse Practitioner
# ...              ...            ...                                    ...
# 1296376   Fall River  United States                       Nurse Supervisor
# 1296377    Lafayette  United States  Assistant Construction Superintendent
# 1296378     Eastport  United States                                   Chef
# 1296379     Colorado  United States                   Occupational Analyst
# 1296380       Malibu  United States                             Cashier Ii
#
#           job_level job_type  \
# 0        Mid senior   Onsite
# 1        Mid senior   Onsite
# 2        Mid senior   Onsite
# 3        Mid senior   Onsite
# 4        Mid senior   Onsite
# ...             ...      ...
# 1296376  Mid senior   Onsite
# 1296377  Mid senior   Onsite
# 1296378  Mid senior   Onsite
# 1296379  Mid senior   Onsite
# 1296380  Mid senior   Onsite
#
#                                                 job_skills  \
# 0        Medical equipment sales, Key competitors, Term...
# 1        Nursing, Bachelor of Science in Nursing, Maste...
# 2        Restaurant Operations Management, Inventory Ma...
# 3        Real Estate, Customer Service, Sales, Negotiat...
# 4        Nursing, BSN, Medical License, Virtual RN, Nur...
# ...                                                    ...
# 1296376  Registered Nurse, BLS certification, Nursing c...
# 1296377  Construction management, Project planning, Est...
# 1296378  Culinary, Chef Director, Menu writing, Cycle o...
# 1296379  Registered Nurse, Analyst, RN Registered Nurse...
# 1296380  Customer service, Communication, Problem solvi...
#
#                                                job_summary       id
# 0        Responsibilities\nJob Description Summary\nJob...        0
# 1        Employment Type:\nFull time\nShift:\nDescripti...        1
# 2        Job Details\nDescription\nWhat You'll Do\nAs a...        2
# 3        Who We Are\nRand Realty is a family-owned brok...        3
# 4        Employment Type:\nFull time\nShift:\n12 Hour N...        4
# ...                                                    ...      ...
# 1296376  TravelNurseSource is working with Adelphi Medi...  1296376
# 1296377  Want to learn more about this role and Jobot? ...  1296377
# 1296378  NEXDINE HOSPITALITY one of the nation's fastes...  1296378
# 1296379  TravelNurseSource is working with Alliant Pers...  1296379
# 1296380  Description: Starting Hourly Rate / Salario po...  1296380
#
# [1296381 rows x 17 columns]

# %%
print("Number of rows in the dataset:", df.shape[0])
print("Number of columns in the dataset:", df.shape[1])
# Out:
# Number of rows in the dataset: 1296381
# Number of columns in the dataset: 17

# %% [markdown]
# ### Overview of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296381 entries, 0 to 1296380
# Data columns (total 17 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   job_link             1296381 non-null  object
#  1   last_processed_time  1296381 non-null  object
#  2   got_summary          1296381 non-null  object
#  3   got_ner              1296381 non-null  object
#  4   is_being_worked      1296381 non-null  object
#  5   job_title            1296381 non-null  object
#  6   company              1296372 non-null  object
#  7   job_location         1296362 non-null  object
#  8   first_seen           1296381 non-null  object
#  9   search_city          1296381 non-null  object
#  10  search_country       1296381 non-null  object
#  11  search_position      1296381 non-null  object
#  12  job_level            1296381 non-null  object
#  13  job_type             1296381 non-null  object
#  14  job_skills           1294296 non-null  object
#  15  job_summary          1296381 non-null  object
#  16  id                   1296381 non-null  int64
# dtypes: int64(1), object(16)
# memory usage: 168.1+ MB

# %% [markdown]
# ### Null value report

# %%
def null_value_report(df):
    missing = pd.DataFrame(df.isna().sum()).reset_index().rename(columns={"index": "column", 0:"Count"})
    missing['Percentage'] = missing['Count'] / df.shape[0] * 100
    display(missing)

# %%
null_value_report(df)
# Out:
#                  column  Count  Percentage
# 0              job_link      0    0.000000
# 1   last_processed_time      0    0.000000
# 2           got_summary      0    0.000000
# 3               got_ner      0    0.000000
# 4       is_being_worked      0    0.000000
# 5             job_title      0    0.000000
# 6               company      9    0.000694
# 7          job_location     19    0.001466
# 8            first_seen      0    0.000000
# 9           search_city      0    0.000000
# 10       search_country      0    0.000000
# 11      search_position      0    0.000000
# 12            job_level      0    0.000000
# 13             job_type      0    0.000000
# 14           job_skills   2085    0.160832
# 15          job_summary      0    0.000000
# 16                   id      0    0.000000

# %% [markdown]
# ## Categorizing columns

# %%
def get_cardinality(df):
    unique = pd.DataFrame(df.nunique()).reset_index().rename(columns={"index": "column", 0:"Count"})
    unique['Unique Percentage'] = unique['Count'] / df.shape[0] * 100
    display(unique)

# %%
# get_cardinality(df)

# %%
ignore_columns = ["job_link", "last_processed_time", "got_summary", "got_ner", "is_being_worked", "id"]
numerical_columns = []

categorical_columns = ["job_title", "company", "job_location", "first_seen", "search_city", "search_country", "search_position", "job_level", "job_type"]
text_columns = ["job_skills", "job_summary"]

# %%
assert(len(numerical_columns + categorical_columns + text_columns + ignore_columns) == df.shape[1])

# %%
print("Number of Numerical columns:", len(numerical_columns))
print("Number of Categorical columns:", len(categorical_columns))
print("Number of Text columns:", len(text_columns))
# Out:
# Number of Numerical columns: 0
# Number of Categorical columns: 9
# Number of Text columns: 2

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Numerical columns

# %%
#There are no numerical fields

# %% [markdown]
# #### Histograms

# %%
def plot_histogram(df, col, log_scale=True):
    sns.set_style("darkgrid")
    sns.histplot(data = df, x=col, bins=20)
    plt.title(f"Distribution of {col}")
    if(log_scale):
        plt.yscale("log")
    plt.show()

# %% [markdown]
# ### Categorical columns

# %% [markdown]
# #### Null value report

# %%
null_value_report(df[categorical_columns])
# Out:
#             column  Count  Percentage
# 0        job_title      0    0.000000
# 1          company      9    0.000694
# 2     job_location     19    0.001466
# 3       first_seen      0    0.000000
# 4      search_city      0    0.000000
# 5   search_country      0    0.000000
# 6  search_position      0    0.000000
# 7        job_level      0    0.000000
# 8         job_type      0    0.000000

# %% [markdown]
# #### Statistics

# %%
df[categorical_columns].describe(include=['object'])
# Out:
#                       job_title          company  job_location  first_seen  \
# count                   1296381          1296372       1296362     1296381
# unique                   565695            88995         28791           6
# top     LEAD SALES ASSOCIATE-FT  Health eCareers  New York, NY  2024-01-14
# freq                       7315            40049         12580      459354
#
#            search_city search_country    search_position   job_level job_type
# count          1296381        1296381            1296381     1296381  1296381
# unique            1018              4               1923           2        3
# top     North Carolina  United States  Account Executive  Mid senior   Onsite
# freq              9495        1105410              19465     1155276  1285565

# %% [markdown]
# #### Count plots

# %%
def plot_count(df, col):
    sns.set_style('darkgrid')
    
    # 1. Create a DataFrame for the **global** category percentages
    percentage_df = (
        df[col]
        .value_counts(normalize=True)  # Proportion of each category
        .mul(100)                      # Convert to percentage
        .rename("percentage")          # Name the column "percentage"
        .reset_index()                 # Convert series to DataFrame
        .rename(columns={"index": col}) # Rename the index column to our category name
    )
    
    # 2. Get the top 20 most frequent categories in the entire dataset
    top_categories = df[col].value_counts().nlargest(20).index.tolist()
    
    # 3. Filter the original DataFrame to include only those top 20 categories
    filtered_df = df[df[col].isin(top_categories)]
    
    # 4. Create the countplot using `order=top_categories`
    plt.figure(figsize=(10, 6))
    ax = sns.countplot(data=filtered_df, y=col, order=top_categories, palette="Set1")
    
    # 5. Annotate each bar with the **global** percentage
    for i, patch in enumerate(ax.patches):
        # The i-th patch corresponds to the i-th category in `top_categories`
        category = top_categories[i]
        
        # Retrieve the global percentage for this category from the percentage_df
        pct_value = percentage_df.loc[percentage_df[col] == category, "percentage"].values[0]
        
        # Bar dimensions
        bar_length = patch.get_width()  # How long the bar is (i.e., the count in `filtered_df`)
        y_center = patch.get_y() + patch.get_height() / 2  # Vertical center of the bar

        # Place the annotation a bit to the right of the bar
        ax.annotate(f"{pct_value:.1f}%", (bar_length, y_center), xytext=(5, 0), textcoords="offset points", ha="left", va="center", fontsize=10, color="black")

    # 6. Final touches: title, labels, layout
    plt.title(f"Top 20 Most Frequent Categories - {col}", fontsize=16)
    plt.xlabel("Count", fontsize=14)
    plt.ylabel(col, fontsize=14)
    plt.tight_layout()
    plt.show()

# %%
for i in categorical_columns:
    if(df[i].nunique() / df.shape[0] < 0.9):
        plot_count(df, i)
# Out:
# /var/folders/t5/tflj5hjs197_vv37fw2sdhdr0000gn/T/ipykernel_50596/8671764.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=filtered_df, y=col, order=top_categories, palette="Set1")
# /var/folders/t5/tflj5hjs197_vv37fw2sdhdr0000gn/T/ipykernel_50596/8671764.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=filtered_df, y=col, order=top_categories, palette="Set1")
# /var/folders/t5/tflj5hjs197_vv37fw2sdhdr0000gn/T/ipykernel_50596/8671764.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=filtered_df, y=col, order=top_categories, palette="Set1")
# /var/folders/t5/tflj5hjs197_vv37fw2sdhdr0000gn/T/ipykernel_50596/8671764.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=filtered_df, y=col, order=top_categories, palette="Set1")
# /var/folders/t5/tflj5hjs197_vv37fw2sdhdr0000gn/T/ipykernel_50596/8671764.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=filtered_df, y=col, order=top_categories, palette="Set1")
# /var/folders/t5/tflj5hjs197_vv37fw2sdhdr0000gn/T/ipykernel_50596/8671764.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=filtered_df, y=col, order=top_categories, palette="Set1")
# /var/folders/t5/tflj5hjs197_vv37fw2sdhdr0000gn/T/ipykernel_50596/8671764.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=filtered_df, y=col, order=top_categories, palette="Set1")
# /var/folders/t5/tflj5hjs197_vv37fw2sdhdr0000gn/T/ipykernel_50596/8671764.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=filtered_df, y=col, order=top_categories, palette="Set1")
# /var/folders/t5/tflj5hjs197_vv37fw2sdhdr0000gn/T/ipykernel_50596/8671764.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=filtered_df, y=col, order=top_categories, palette="Set1")

# %% [markdown]
# ### Text columns

# %% [markdown]
# #### Null value report

# %%
null_value_report(df[text_columns])
# Out:
#         column  Count  Percentage
# 0   job_skills   2085    0.160832
# 1  job_summary      0    0.000000

# %% [markdown]
# #### Text lengths

# %%
temp = df[text_columns].fillna("").copy()
for i in text_columns:
    temp[f"{i}_len"] = temp[i].apply(lambda x: len(x))
    
temp[text_columns + [f"{i}_len" for i in text_columns]]
# Out:
#                                                 job_skills  \
# 0        Medical equipment sales, Key competitors, Term...
# 1        Nursing, Bachelor of Science in Nursing, Maste...
# 2        Restaurant Operations Management, Inventory Ma...
# 3        Real Estate, Customer Service, Sales, Negotiat...
# 4        Nursing, BSN, Medical License, Virtual RN, Nur...
# ...                                                    ...
# 1296376  Registered Nurse, BLS certification, Nursing c...
# 1296377  Construction management, Project planning, Est...
# 1296378  Culinary, Chef Director, Menu writing, Cycle o...
# 1296379  Registered Nurse, Analyst, RN Registered Nurse...
# 1296380  Customer service, Communication, Problem solvi...
#
#                                                job_summary  job_skills_len  \
# 0        Responsibilities\nJob Description Summary\nJob...             441
# 1        Employment Type:\nFull time\nShift:\nDescripti...             431
# 2        Job Details\nDescription\nWhat You'll Do\nAs a...            1155
# 3        Who We Are\nRand Realty is a family-owned brok...             305
# 4        Employment Type:\nFull time\nShift:\n12 Hour N...             116
# ...                                                    ...             ...
# 1296376  TravelNurseSource is working with Adelphi Medi...             280
# 1296377  Want to learn more about this role and Jobot? ...             297
# 1296378  NEXDINE HOSPITALITY one of the nation's fastes...             757
# 1296379  TravelNurseSource is working with Alliant Pers...             357
# 1296380  Description: Starting Hourly Rate / Salario po...             647
#
#          job_summary_len
# 0                   4602
# 1                   2950
# 2                   4571
# 3                   3944
# 4                   1762
# ...                  ...
# 1296376             2224
# 1296377             2813
# 1296378             4856
# 1296379             2143
# 1296380             8294
#
# [1296381 rows x 4 columns]

# %%
temp["num_of_skills"] = temp["job_skills"].apply(lambda x: len(x.split(",")))

# %% [markdown]
# #### Text length statistics

# %%
temp[[f"{i}_len" for i in text_columns] + ["num_of_skills"]].describe(percentiles=[0.05, 0.25, 0.5, 0.75, 0.95]).round(2)
# Out:
#        job_skills_len  job_summary_len  num_of_skills
# count      1296381.00       1296381.00     1296381.00
# mean           413.73          3818.55          20.77
# std            269.08          2302.56          11.65
# min              0.00            21.00           1.00
# 5%             123.00          1028.00           7.00
# 25%            245.00          2211.00          13.00
# 50%            357.00          3382.00          19.00
# 75%            511.00          4927.00          25.00
# 95%            886.00          7958.00          41.00
# max           9939.00         23748.00         463.00

# %% [markdown]
# #### Text length histograms

# %%
for i in [f"{i}_len" for i in text_columns] + ["num_of_skills"]:
    plot_histogram(temp, i)

# %% [markdown]
# ## Sampling data based on job titles

# %%
print("Total available job titles:", df['job_title'].nunique())
# Out:
# Total available job titles: 565695

# %% [markdown]
# We can see that there are almost 500k different job titles. But we do not need all those job titles. Since the plan is to generate synthetic data, small number of records would be sufficient

# %%
jobs = df['job_title'].value_counts()
jobs
# Out:
# job_title
# LEAD SALES ASSOCIATE-FT                                                                                    7315
# Shift Manager                                                                                              5500
# First Year Tax Professional                                                                                5351
# Customer Service Representative                                                                            5165
# Assistant Manager                                                                                          5067
#                                                                                                            ...
# Senior Warehouse Operations Manager                                                                           1
# Senior Space Domain Awareness (SDA) / Orbital Analyst                                                         1
# Operational Technology Performance Analyst                                                                    1
# Shift Lead - Eastside                                                                                         1
# On-Demand: Guest Advocate (Cashier), General Merchandise, Fulfillment, Food and Beverage, Style (T2632)       1
# Name: count, Length: 565695, dtype: int64

# %% [markdown]
# We can observe that there are many job titles that are more frequent or very rare in the dataset. So, lets filter out records based on job titles that have less than 400 records each. Therefore, we are ignoring most of the frequently appearing jobs

# %%
#ignoring higly repetitive job titles and less frequent job titles
#Selecting top 1500 most repetitive job titles
titles_with_less_than_400_count = jobs[jobs.values<400].nlargest(1500)
titles_with_less_than_400_count
# Out:
# job_title
# Travel RN - Med Surg / Telemetry                                        397
# District Manager                                                        397
# Travel Allied Health Professional - Nuclear Medicine Technologist       395
# Physiotherapist                                                         392
# HR Business Partner                                                     391
#                                                                        ...
# Ward Manager                                                             52
# Family Nurse Practitioner / Physician Assistant - Growth Opportunity     52
# General Practitioner (DPA)                                               52
# Dentist - DDS / DMD                                                      52
# Locum General Radiographer                                               52
# Name: count, Length: 1500, dtype: int64

# %%
#Selecting those records where job titles have less than 400 cardinality
selected_titles_df = df[df['job_title'].isin(titles_with_less_than_400_count.index)]

#Creating summary_len column to understand the distribution
selected_titles_df['summary_len'] = selected_titles_df['job_summary'].apply(lambda x: len(x)).copy()
# Out:
# /var/folders/t5/tflj5hjs197_vv37fw2sdhdr0000gn/T/ipykernel_50596/1903999843.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_titles_df['summary_len'] = selected_titles_df['job_summary'].apply(lambda x: len(x)).copy()

# %% [markdown]
# We can obtain a more robust dataset sample by selecting only those records whose summary length falls between certain length. This ensures that the job summary is detailed.

# %%
#filtering to obtain records that have summary length >= 2000 and <= 7000
selected_titles_df = selected_titles_df[(selected_titles_df['summary_len'] >= 2000) & (selected_titles_df['summary_len'] <= 7000)].copy()
selected_titles_df
# Out:
#                                                   job_link  \
# 3        https://www.linkedin.com/jobs/view/independent...
# 20       https://www.linkedin.com/jobs/view/chef-de-cui...
# 30       https://www.linkedin.com/jobs/view/cheese-spec...
# 34       https://www.linkedin.com/jobs/view/retail-dist...
# 40       https://www.linkedin.com/jobs/view/travel-rn-l...
# ...                                                    ...
# 1296269  https://uk.linkedin.com/jobs/view/production-p...
# 1296275  https://www.linkedin.com/jobs/view/store-manag...
# 1296347  https://www.linkedin.com/jobs/view/sales-repre...
# 1296358  https://www.linkedin.com/jobs/view/ft-center-s...
# 1296375  https://www.linkedin.com/jobs/view/associate-a...
#
#                    last_processed_time got_summary got_ner is_being_worked  \
# 3        2024-01-21 07:40:00.308133+00           t       t               f
# 20       2024-01-21 07:12:35.170823+00           t       t               f
# 30       2024-01-21 06:01:14.692423+00           t       t               f
# 34       2024-01-21 07:12:35.189652+00           t       t               f
# 40       2024-01-21 07:12:37.537623+00           t       t               f
# ...                                ...         ...     ...             ...
# 1296269  2024-01-20 04:01:08.913697+00           t       t               f
# 1296275  2024-01-20 05:12:47.255315+00           t       t               f
# 1296347  2024-01-20 13:46:06.129745+00           t       t               f
# 1296358  2024-01-20 13:46:10.289403+00           t       t               f
# 1296375   2024-01-20 15:20:54.32033+00           t       t               f
#
#                                   job_title                          company  \
# 3             Independent Real Estate Agent       Howard Hanna | Rand Realty
# 20                          Chef de Cuisine               Goodwin Recruiting
# 30                        Cheese Specialist                          Safeway
# 34       RETAIL DISTRICT MANAGER UNASSIGNED                   Dollar General
# 40               Travel RN - Long Term Care                CoreMedical Group
# ...                                     ...                              ...
# 1296269                  Production Planner  Eat Real + PROPER | WARP Snacks
# 1296275           Store Manager in Training              O'Reilly Auto Parts
# 1296347                Sales Representative  American Fidelity Sales Careers
# 1296358         FT Center Store Manager (H)                        Food Lion
# 1296375           Associate Account Manager                          Lockton
#
#                               job_location  first_seen    search_city  \
# 3                     Englewood Cliffs, NJ  2024-01-16      Pinehurst
# 20                          Brookfield, WI  2024-01-14      Milwaukee
# 30                          Mount Airy, MD  2024-01-14      Frederick
# 34                             Newport, NH  2024-01-14  New Hampshire
# 40                          Barnstable, MA  2024-01-14     Barnstable
# ...                                    ...         ...            ...
# 1296269  Nuneaton, England, United Kingdom  2024-01-14       Hastings
# 1296275                        Concord, NH  2024-01-14        Laconia
# 1296347                        Altoona, PA  2024-01-14   Pennsylvania
# 1296358                       Powhatan, VA  2024-01-14       Abingdon
# 1296375                    Minneapolis, MN  2024-01-15    Lake Forest
#
#          search_country             search_position   job_level job_type  \
# 3         United States           Real-Estate Clerk  Mid senior   Onsite
# 20        United States                   Sous Chef  Mid senior   Onsite
# 30        United States  Special Effects Specialist  Mid senior   Onsite
# 34        United States         Pressure Supervisor  Mid senior   Onsite
# 40        United States                  Nurse Head  Mid senior   Onsite
# ...                 ...                         ...         ...      ...
# 1296269  United Kingdom                   Scheduler  Mid senior   Onsite
# 1296275   United States           Bakery Supervisor  Mid senior   Onsite
# 1296347   United States  Group-Sales Representative   Associate   Onsite
# 1296358   United States          Manager Employment  Mid senior   Onsite
# 1296375   United States           Director Athletic  Mid senior   Onsite
#
#                                                 job_skills  \
# 3        Real Estate, Customer Service, Sales, Negotiat...
# 20       Chef de Cuisine, Executive Sous Chef, Hospital...
# 30       Retail, Grocery, Customer service, Merchandisi...
# 34       Retail Management, Profit and Loss Management,...
# 40       Travel Nursing, Long Term Care, RN (Registered...
# ...                                                    ...
# 1296269  Production Planning, ERP (Access), Scheduling,...
# 1296275  Sales, Leadership, Hiring, Training, Safety, C...
# 1296347  Sales, Insurance, Account Management, Business...
# 1296358  Grocery Department Management, Hiring and Trai...
# 1296375  Account Management, Commercial Insurance, Micr...
#
#                                                job_summary       id  \
# 3        Who We Are\nRand Realty is a family-owned brok...        3
# 20       To Apply for this Job Click Here\nMidwest Hosp...       20
# 30       CHEESE SPECIALIST\nWhy you will choose us:\nAl...       30
# 34       Dollar General Corporation has been delivering...       34
# 40       Core Medical Group is seeking a travel nurse R...       40
# ...                                                    ...      ...
# 1296269  About WARP\nPROPER and Eat Real were born out ...  1296269
# 1296275  Assist store manager in areas of sales, appear...  1296275
# 1296347  American Fidelity Assurance is now looking for...  1296347
# 1296358  Address:\nUSA-VA-Powhatan-1800 South Creek One...  1296358
# 1296375  Responsibilities\nYour Responsibilities\nAssoc...  1296375
#
#          summary_len
# 3               3944
# 20              2789
# 30              3714
# 34              4372
# 40              3163
# ...              ...
# 1296269         2614
# 1296275         4067
# 1296347         3218
# 1296358         5770
# 1296375         3407
#
# [125380 rows x 18 columns]

# %%
#saving the data
selected_titles_df.to_csv(f"{path}/data/kaggle_linkedin_jd_skills_dataset/merged_selected_jd.csv", index=False)
